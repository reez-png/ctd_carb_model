# %% [markdown]
# # Step 01 — Prepare data
#
# Load the merge tool's master table, resolve predictors/responses, label measured vs calculated, drop QC-failed rows. Produces the model-ready dataset everything else uses.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
import pandas as pd

# %%
# --- parameters ---
MASTER = r'..\..\ctd_carb_merge\merged_check\data\merged_ctd_carbonate.csv'  # your merge output

# %%
from ctd_carb_model import data
df = pd.read_csv(MASTER)
ds = data.prepare(df)
print(data.summarise(ds))
# save the prepared frame for the next steps
ds.frame.to_csv('../outputs/model_ready.csv', index=False)

# %% [markdown]
# Check the summary: are your predictors and responses all resolved? Note which responses are **calculated** (DIC/pCO2/omega) — those are recomputed later, not modelled directly.
